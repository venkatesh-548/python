# %%
import datetime
class Bank:
    bname="CANARA BANK"
    branch="hyd"
    branchcode="1600"
    ifsc_code="CNRB001600"
    toll_no=11008734787
    roi=7
    no_cust=0
    cust_details={}
    cust_transactions={}
    def __init__(self,name,age,email,phone,address,aadhar,pancard,dob,gender,pin,bal=1000):
        self.name=name
        self.age=age
        self.email=email
        self.phone=phone
        self.address=address
        self.aadher=aadhar
        self.pancard=pancard
        self.dob=dob
        self.gender=gender
        self.pin=pin
        self.bal=bal
        self.no_cust_inc()
        self.account_no=100+self.no_cust
        self.concat_cust_details(self.account_no,self)
    @classmethod
    def no_cust_inc(cls):
        cls.no_cust+=1
    @classmethod
    def concat_cust_details(cls,acc_no,b):
        cls.cust_details[acc_no]=b

    @classmethod
    def change_ROI(cls):
        cls.roi=int(input("enter the roi:"))
        print("ROI is changed:")

    @classmethod
    def check_bal(cls):
        acc_no=int(input("enter the account no:"))
        pin=int(input("enter the pin:"))
        for i in cls.cust_details:
            res=cls.cust_details[i]
            if res.account_no==acc_no and res.pin==pin:
                print(res.account_no,"bal is:",res.bal)
                return
        else:
            print("invalid accountno or pin")
    @classmethod
    def concat_cust_tran(cls,acc_no,data):
        if acc_no in cls.cust_transactions:
            cls.cust_transactions[acc_no]+=[data]
            print(acc_no,data)
        else:
            cls.cust_transactions[acc_no]=data
            print(acc_no,data)

    def deposit(self,count=0):
        if count==3:
            return
        amt=int(input("enter deposit amount:"))
        if amt>=100:
            self.bal+=amt
            print("transaction success")
            print("balance after deposit:",self.bal)
            self.concat_cust_tran(self.account_no,{'date': datetime.datetime.now(),'type':'Deposit','Amount':amt,"Balance":self.bal})
            return
        else:
            print("amount should be minimum 100 rps")
            print("transaction failed")
            return self.deposit(count+1)
    def withdraw(self,count=0):
        if count==3:
            return
        amt=int(input("enter the withdraw amount:"))
        if amt>=100:
            self.bal-=amt
            print("transaction successful")
            print("balance after withdraw:",self.bal)
            self.concat_cust_tran(self.account_no,{'date':datetime.datetime.now(),'type':'withdraw','Amount':amt,"Balance":self.bal})
            print("transaction successful")
            return
        else:
            print("the amount should be minimum 100")
            print("transaction failed")
            return self.withdraw(count+1)
    
    def mini_statement(self):
        print("Date".center(25),"Type".center(12),"Amount".center(12),"Balance".center(15),sep=" | ")
        print('='*80)
        for i in self.cust_transactions[self.account_no]: 
            print(str(i["date"]).center(25),str(i["type"]).center(12),str(i["amount"]).center(12),str(i["bal"]).center(15),sep=" | ")
            print('='*80)
    def check_bal(self):
        print("Your Current Balance:",self.bal)
    
    def pin_change(self):
        old=int(input("enter old pin:"))
        if self.pin==old:
            self.pin=int(input("enter the new pin:"))
            print("pin changed")
            print("transaction success")
        else:
            print("transaction failed")

    def cust_update(self):
        n=int(input("choose the option\n1.Name\n2.Phone\n3.Email\n4.Address\n5.Exit"))
        match n:
            case 1:
                self.name=input("enter the name:")
            case 2:
                self.phone=int(input("enter phone number:"))
            case 3:
                self.email=input("enter email:")
            case 4:
                self.address=input("enter address")
            case _:
                return
        return self.cust_update()
    def account_details(self):
        print("Account No:",self.account_no)
        print("Name:",self.name)
        print("Age:",self.age)
        print("Email:",self.email)
        print("Phone:",self.phone)
        print("Balance:",self.bal)
        print("IFSC:",self.ifsc_code)
        print("Pan:",self.pancard)
        print("Aadhar:",self.aadher)
        print("Address:",self.address)
    def transfer(self):
        print("your current balance",self.bal)
        acc_no=int(input("enter the benificiary acccount no:"))
        ifsc=input("enter the benificiary ifsc code:")
        if acc_no in self.cust_details and ifsc==self.cust_details[acc_no].ifsc_code:
            amt=int(input("enter the amount to transfer:"))
            if self.bal>=amt:
                other=self.cust_details[acc_no]
                other.bal+=amt
                self.bal-=amt
                self.concat_cust_tran(self.account_no, {'date':datetime.datetime.now(),"type":'Transfer(w)','amount':amt,"Balance":self.bal})
                self.concat_cust_tran(self.account_no, {'date':datetime.datetime.now(),"type":'Transfer(d)','amount':amt,"Balance":other.bal})
                print("transaction success")
                print("after transfer the current bal:",self.bal)
                return
            else:
                print("transaction failed")
                print("insuffient funds")
        else:
            print("invalid account no or ifsc code ")
            return
        
    @classmethod
    def home(cls,self):
        n=int(input("choose the option:\n1.Account Details\n2.check balance\n3.deposit\n4.Withdraw\n5.mini statement\n6pinchange\n7.cust_update8.Check ROI\n9.Transfer\n10.Exit"))
        print("*"*100)
        match n:
            case 1:
                self.account_details()
            case 2:
                self.check_bal()
            case 2:
                self.deposit()
            case 4:
                self.withdraw()
            case 5:
                self.mini_statement()
            case 6:
                self.pin_change()
            case 7:
                self.cust_update()
            case 8:
                self.change_ROI()
            case 9:
                self.transfer()
            case _:
                return
        return cls.home(self)
b=Bank("venky",23,'venky@gmail.com',7465784367,"hyderabad",980860790546,'PANC2345O9','15-07-2001','male',1234)
b1=Bank("venkat",25,'venkat@gmail.com',7465784368,"dilshuknagar",980860790546,'PANC234510','15-07-2002','male',9876)
print(b.__dict__)
print(b1.__dict__)
# print(Bank.account_no)
# print(Bank.cust_details)
# print(Bank.no_cust)
# Bank.check_bal()
Bank.deposit(b)
# Bank.withdraw(b)
Bank.mini_statement(b)
# Bank.transfer(b)
# Bank.mini_statement(b)
# Bank.check_bal(b)
# Bank.pin_change(b)
# Bank.account_details(b)
# Bank.concat_cust_details(b)
# Bank.concat_cust_tran(b)
# def main(cls):
#     acc_no=int(input('enter the pin no:'))
#     pin=int(input("enter pin number:"))
#     if acc_no in cls.cust_details and cls.cust_details[acc_no].pin==pin:
#         self=cls.cust_details[acc_no]
#         cls.home(self)
#     else:
#         print("invalid account no or pin")
# main(Bank)

# %%
class Resturent:
    def __init__(self,un,pw):
        self.username="venky"
        self.pas=1234
        self.un=un
        self.pw=pw
    def Validation(self):
        if self.un==self.username and self.pw==self.pas:
            print("you are a valid user")
        else:
            print("you are not valid user")
un=input("enter username:")
pw=int(input("enter pin:"))
obj=Resturent(un,pw)
obj.Validation()
# Out:
# you are not valid user

# %%
class resturent:
    rname="FOOD'SS DEN"
    sno="1274652"
    address="dilshuknagar"
    phone=897627816
    cart={}
    def __init__(self):
        self.biryanis={"chiken65":270,
    "veg dum biryani":200,
    "paneer_biryani":270,
    "chiken dum biryani":230,
    "chiken dum biryani jumbo":400}
    def veg_starter(self):
        print('Veg Starter'," "*10,'Price')
        print("-"*30)
        print("veg biryani"," "*8,150)
        print("veg manchria"," "*7,100)
        print("chilli veg"," "*9,130)
        print("veg 65"," "*13,150)
        print("panner manchuria"," "*3,200)
        print("paneer 65"," "*10,200)
        print("chilli paneer"," "*6,200)
    def Non_veg_starter(self):
        print("Non-Veg Starter"," "*10,'Price')
        print("*"*37)
        print("chiken manchria"," "*10,200)
        print("chilli chiken  "," "*10,250)
        print("chiken 65      "," "*10,250)
        print("ginger chiken  "," "*10,350)
        print("garlic chiken  "," "*10,330)
        print("pepper chiken  "," "*10,380)
        print("chiken deep fry"," "*10,350)
        print("chiken lollypop"," "*10,250)
        print("gongura chiken "," "*10,280)
    def biryani(self):
        print("Biryani"," "*22,'Price')
        print("-"*40)
        print("chiken 65 biryani       "," "*5,280)
        print("veg dum biryani         "," "*5,280)
        print("paneer biryani          "," "*5,280)
        print("chiken dum biryani      "," "*5,280)
        print("chiken dum biryani jumbo"," "*5,280)
        print("chiken manchria         "," "*5,280)
        print("chiken manchria         "," "*5,280)
        print("chiken manchria         "," "*5,280)
    def display(self):
        res=0
        ord={}
        ord1={}
        while True:
            opt=int(input("choose option\n1.choose:\n2.show_cart\n3.confirm items\n4.bill\n5.Exit:"))
            if opt==1:
                n=input("enter user input:")
                if n in self.biryanis:
                    res+=self.biryanis[n]
                    ord1.update({n:self.biryanis[n]})
                    if n in ord:
                        ord[n]+=1
                    else:
                        ord[n]=1
                else:
                    print("item not present")
            elif opt==2:
                print("the selected items are:",ord1)
            elif opt==3:
                print("the quantity of the items:",ord)
            elif opt==4:
                print("the total bill of the items are:",res)
            elif opt==5:
                break
            # for i in range(0,n):
            #     res+=self.biryanis[]
        # for i in self.biryanis:
            
        #     print(i)
                # res+=self.biryanis[n]
# obj=resturent()
# obj.veg_starter()
# obj.Non_veg_starter()
# obj.biryani()
# obj.display()
# print(res.__dict__)


# while True:
#     option=int(input("enter choice\n1.veg_starter\n2.non veg\n3.biryanis\n4.exit"))
#     print("*"*50)
#     if option==1:
#         obj.veg_starter()
#     elif option==2:
#         obj.Non_veg_starter()
#     elif option==3:
#         obj.biryani()
#     elif option==4:
#         print("----thanks for visiting my resturent-----")
#         break
#     else:
#         print("invalid option...plz choose valid option")

# %%
class Resturent:
    def __init__(self,un,pw):
        self.username="venky"
        self.pas=1234
        self.un=un
        self.pw=pw
    def Validation(self):
        if self.un==self.username and self.pw==self.pas:
            print("you are a valid user")
            obj=resturent()
            while True:
                option=int(input("enter choice\n1.veg_starter\n2.non veg\n3.biryanis\n4.exit"))
                print("*"*50)
                if option==1:
                    obj.veg_starter()
                elif option==2:
                    obj.Non_veg_starter()
                elif option==3:
                    obj.biryani()
                elif option==4:
                    obj.display()
                elif option==5:
                    print("----thanks for visiting my resturent-----")
                    break
                else:
                    print("invalid option...plz choose valid option")
        else:
            print("you are not valid user")
un=input("enter username:")
pw=int(input("enter pin:"))
obj=Resturent(un,pw)
obj.Validation()

# %%
def display(self):
        n=input("enter user input:")
        if n in self.biyanis:
            # for i in self.biryanis:
            #     print(self.biryanis[i])
            #     print(i)
            res+=self.biryanis["chiken65"]+self.biryanis["veg dum biryani"]
        print("the bill is:",res)

# %%
d={"chiken 65 biryani":270,
    "veg dum biryani":200,
    "paneer_biryani":270,
    "chiken dum biryani":230,
    "chiken dum biryani jumbo":400}
ord={}
ord.update({"a":10})
print(ord)
for i,j in d.items():
    print(f'{i} X {j}')
print(ord)
# Out:
# {'a': 10}
# chiken 65 biryani X 270
# veg dum biryani X 200
# paneer_biryani X 270
# chiken dum biryani X 230
# chiken dum biryani jumbo X 400
# {'a': 10}

# %%
class resturent:
    rname="FOOD'SS DEN"
    sno="1274652"
    address="dilshuknagar"
    phone=897627816
    cart={}
    def __init__(self):
        self.biryanis={"chiken65":270,
    "veg dum biryani":200,
    "paneer biryani":270,
    "chiken dum biryani":230,
    "chiken dum biryani jumbo":400,
    "veg biryani":150,"veg manchria":100,
    "chilli veg":130,"veg 65":150,
    "panner manchuria":200,
    "paneer 65":200,"chilli paneer":200,
    "chiken manchria":200,"chilli chiken":280,
    "chiken 65":280,"chiken deep fry":300,"chiken lollypop":300,"gongura chiken":250}
    def veg_starter(self):
        print('Veg Starter'," "*10,'Price')
        print("-"*30)
        print("veg biryani"," "*8,150)
        print("veg manchria"," "*7,100)
        print("chilli veg"," "*9,130)
        print("veg 65"," "*13,150)
        print("panner manchuria"," "*3,200)
        print("paneer 65"," "*10,200)
        print("chilli paneer"," "*6,200)
    def Non_veg_starter(self):
        print("Non-Veg Starter"," "*10,'Price')
        print("-"*37)
        print("chiken manchria"," "*10,200)
        print("chilli chiken  "," "*10,250)
        print("chiken 65      "," "*10,250)
        print("ginger chiken  "," "*10,350)
        print("garlic chiken  "," "*10,330)
        print("pepper chiken  "," "*10,380)
        print("chiken deep fry"," "*10,350)
        print("chiken lollypop"," "*10,250)
        print("gongura chiken "," "*10,280)
    def biryani(self):
        print("Biryani"," "*22,'Price')
        print("-"*40)
        print("chiken 65 biryani       "," "*5,280)
        print("veg dum biryani         "," "*5,280)
        print("paneer biryani          "," "*5,280)
        print("chiken dum biryani      "," "*5,280)
        print("chiken dum biryani jumbo"," "*5,280)
        print("chiken manchria         "," "*5,280)
        print("chiken manchria         "," "*5,280)
        print("chiken manchria         "," "*5,280)
    def display(self):
        res=0
        ord={}
        ord1={}
        while True:
            try:
                opt=int(input("choose the option\n1.choose items:\n2.cart\n3.confirm\n4.bill\n5.exit:"))
            except ValueError:
                print("plz provide numbers only")
            except:
                print("enter valid inputs only")
            if opt==1:
                try:
                    n=input("enter the item you want:")
                except UnboundLocalError:
                    print("plz enter valid data")
                if n in self.biryanis:
                    res+=self.biryanis[n]
                    ord1.update({n:self.biryanis[n]})
                    if n in ord:
                        ord[n]+=1
                    else:
                        ord[n]=1
                else:
                    print("item not present")
            elif opt==2:
                print("the selected items are")
                print("-"*30)
                for it,pri in ord1.items():
                    print(f'{it} {pri}')
            elif opt==3:
                print("the quantity of the items:")
                print("-"*30)
                for item,quan in ord.items():
                    print(f'{item} X {quan} = {self.biryanis[item]*quan}')
            elif opt==4:
                print("the total bill of the items are:",res)
            elif opt==5:
                break

# %%
class payment:
    def __init__(self,upi,pin):
        self.upi=upi
        self.pin=pin
        self.c_pin=9876
        self.c_upi='7386624002@paytm'
    def valid(self):
        if self.c_pin==self.pin and self.c_upi==self.upi:
            print("payment successful")
            print("your order is placed")
        else:
            print("wrong upi or pin")

# %%
class Resturent:
    def __init__(self,un,pw):
        self.username="venky"
        self.pas=1234
        self.un=un
        self.pw=pw
    def Validation(self):
        if self.un==self.username and self.pw==self.pas:
            print("you are a valid user")
            obj=resturent()
            while True:
                try:
                    option=int(input("enter choice\n1.veg_starter\n2.non veg\n3.biryanis\n4.display\n5.payment\n6.exit"))
                except ValueError:
                    print("please provide numbers only")
                except:
                    print("enter valid inputs")
                print("*"*50)
                if option==1:
                    obj.veg_starter()
                elif option==2:
                    obj.Non_veg_starter()
                elif option==3:
                    obj.biryani()
                elif option==4:
                    obj.display()
                elif option==5:
                    upi=input("enter upi:")
                    pin=int(input("enter pin:"))
                    obj1=payment(upi,pin)
                    obj1.valid()
                elif option==6:
                    print("----thanks for visiting my resturent-----")
                    break
                else:
                    print("invalid option...plz choose valid option")
        else:
            print("you are not valid user")
try:
    un=input("enter username:")
    pw=int(input("enter pin:"))
except ValueError:
    print("enter valid input")
obj=Resturent(un,pw)
obj.Validation()
# Out:
# you are a valid user
# **************************************************
# Veg Starter            Price
# ------------------------------
# veg biryani          150
# veg manchria         100
# chilli veg           130
# veg 65               150
# panner manchuria     200
# paneer 65            200
# chilli paneer        200
# **************************************************
# Non-Veg Starter            Price
# -------------------------------------
# chiken manchria            200
# chilli chiken              250
# chiken 65                  250
# ginger chiken              350
# garlic chiken              330
# pepper chiken              380
# chiken deep fry            350
# chiken lollypop            250
# gongura chiken             280
# **************************************************
# Biryani                        Price
# ----------------------------------------
# chiken 65 biryani              280
# veg dum biryani                280
# paneer biryani                 280
# chiken dum biryani             280
# chiken dum biryani jumbo       280
# chiken manchria                280
# chiken manchria                280
# chiken manchria                280
# **************************************************
# the selected items are
# ------------------------------
# chiken lollypop 300
# the quantity of the items:
# ------------------------------
# chiken lollypop X 2 = 600
# the total bill of the items are: 600
# **************************************************
# payment successful
# your order is placed
# **************************************************
# ----thanks for visiting my resturent-----

# %%
class College:
    cname="nvr college"
    cid="197T1A0100"
    caddress="tenali"
    no_stud=0
    stud_details={}
    def __init__(self,sname,phone,email,address,mark1,mark2,mark3):
        self.sname=sname
        self.phone=phone
        self.email=email
        self.address=address
        self.mark1=mark1
        self.mark2=mark2
        self.mark3=mark3
        self.no_of_stud()
        self.roll_no=100+self.no_stud
        self.set_stud_details(self.roll_no,self)
    @classmethod
    def no_of_stud(cls):
        cls.no_stud+=1
    @classmethod
    def set_stud_details(cls,roll_num,self):
        cls.stud_details[roll_num]=self
    def calculate_total(self):
        tot=self.mark1+self.mark2+self.mark3
        # print("The Total Marks Of the Student is:",tot)
        self.per=(tot/300)*100
        return tot
    def display_stud_details(self):
        print("Student Name:",self.sname)
        print("Student Roll_No:",self.roll_no)
        print("Student Phone:",self.phone)
        print("Student Address:",self.address)
        print("Student Total Marks:",self.calculate_total())
        print("student Percentage:",self.per)
    
    def display_specific_stud(self):
        print()
    def Modify_marks(self):
        while True:
            opt=input("enter your choice:1.marks1\n2.maeks2\n3.marks3\n4.exit")
            if opt==1:
                self.mark1=int(input("enter marks1:"))
            elif opt==2:
                self.mark2=int(input("enter marks2:"))
            elif opt==3:
                self.mark3=int(input("enter marks3:"))
            elif opt==4:
                break
            else:
                print("enter a vaild option")





    
obj=College("venky",73726872,'venky@gmail.com',"vizag",85,80,75)
obj.__dict__
# obj.calculate_total()
# College.stud_details
# obj.display_stud_details()
obj.Modify_marks()

# %%
import datetime
class Bank:
    bann_name="CANARABANK"
    branch="hyd"
    branch_code=1600
    ifsc="CNRB001600"
    roi=7
    no_cust=0
    cust_details={}
    cust_transactions={}
    def __init__(self,name,age,email,phone,address,adhaar,pancard,dob,gender,pin,bal=0):
        self.name=name
        self.age=age
        self.email=email
        self.phone=phone
        self.address=address
        self.adhaar=adhaar
        self.pancard=pancard
        self.dob=dob
        self.gender=gender
        self.pin=pin
        self.bal=bal
        self.no_cust_inc()
        self.account_no=100+self.no_cust
        self.concat_cust_details(self.account_no,self)

    @classmethod
    def no_cust_inc(cls):
        cls.no_cust+=1

    @classmethod
    def concat_cust_details(cls,acc_no,obj):
        cls.cust_details[acc_no]=obj

    @classmethod
    def change_ROI(cls):
        cls.roi=int(input("enter the RoI"))
        print("Roi is changed")
        
    @classmethod
    def check_bal(cls): 
        acc_no=int(input("enter the Account No:"))
        pin=int(input("enter the Account Pin No:"))
        for i in cls.cust_details:
            res=cls.cust_details[i]
            if res.account_no==acc_no and res.pin==pin:
                print(res.account_no,"balance is:",res.bal)
                return
        else:
            print("Invalid acc_no or pin")

    @classmethod
    def concat_cust_trans(cls,acc_no,data):
        if acc_no in cls.cust_transactions: 
            cls.cust_transactions[acc_no]+=[data] 
            print(acc_no,data)
        else:
            cls.cust_transactions[acc_no]=[data] 
            print(acc_no,data)
        
    def deposit(self,count=0):
        if count==3:
            return
        amt=int(input("Enter the deposit Amount"))
        if amt>=100:
            self.bal+=amt
            print("+Amount Deposited")
            self.concat_cust_trans(self.account_no,{"date":datetime.datetime.now(),"type":"deposit","amount":amt,"bal":self.bal})
            return
        else:
            print("Amount should be Minimum 100 Rupees")
            return self.deposit(count+1)
        
        
    def withdraw(self,count=0):
        if count==3:
            return
        amt=int(input("Enter the withdrawl Amount"))
        if amt>=100 and self.bal>=amt:
            self.bal-=amt
            self.concat_cust_trans(self.account_no,{"date":datetime.datetime.now(),"type":"withdraw","amount":amt,"bal":self.bal})
            print("-Amount Withdrawal")
            return
        else:
            print("Amount should be Minimum 100 Rupees")

    def mini_statement(self):
        print("Date".center(25),"Type".center(12),"Amount".center(12),"Balance".center(15),sep=" | ")
        print('='*80)
        if self.account_no in self.cust_transactions:
            for i in self.cust_transactions[self.account_no]: 
                print(str(i["date"]).center(25),str(i["type"]).center(12),str(i["amount"]).center(12),str(i["bal"]).center(15),sep=" | ")
                print('='*80)
        else:
            print("no transactions yet")
    
    def check_bal(self):
        print("Your Current Balance is :",self.bal)

    def pin_change(self):
        oldpin = int(input("Enter your Old PIN"))
        if oldpin == self.pin:
            self.pin =int(input("Enter Your New PIN"))
            print("Your PIN is Changed")
        else:
            print("Incorrect Old PIN")
    
    def cust_update(self):
        n=int(input("Choose the option: \n1.Name\n2.Phone\n3.Email\n4.Address\n5.Exit"))
        match n:
            case 1:
               self.name = input("Enter new Name")
            case 2:
                self.phone =int( input("Enter new Phone Number"))
            case 3:
                self.email = input("Enter new Email ID")
            case 4:
                self.address = input("Enter new Address")
            case _:
                return   
        return self.cust_update()
    def account_details(self):
        print("Account no :",self.account_no)
        print("Name :",self.name)
        print("Age :",self.age)
        print("Email :",self.email)
        print("Phone :",self.phone)
        print("Address :",self.address)
        print("Balance:",self.bal)
        print("IFSC:",self.ifsc_code)
        print("Pan:",self.pancard)
        print("Aadhar:",self.aadher)

    def transfer(self):
        print("your current balance:",self.bal)
        acc_no=int(input("Enter the Beneficiary Accno : "))
        ifsc_code=input("Enter the Beneficiary IFSC :")
        if acc_no in self.cust_details and ifsc_code == self.cust_details[acc_no].ifsc:
            amt=int(input("Enter the Transfer Amount:"))
            if self.bal>=amt:
                other=self.cust_details[acc_no]
                other.bal+=amt
                self.bal-=amt
                print("Transfer Successful  :) ")
                print("After transfer current balance",self.bal)
                self.concat_cust_trans(self.account_no,{"date":datetime.datetime.now(),"type":"Transfer(W)","amount":amt,"bal":self.bal})
                self.concat_cust_trans(other.account_no,{"date":datetime.datetime.now(),"type":"Transfer(d)","amount":amt,"bal":other.bal})
                return
            else:
                print("in sufficient funds to transfer")
                return
        else:
            print("Invalid Account or IFSC code")
    @classmethod
    def home(cls,self):
        n=int(input("choose the option: \n0.AcccountDetails\n1.Check Bal\n2.Deposit\n3.withdraw\n4.mini Statement\n5.Update\n6.Pin Change\n7.check ROI \n8.Transfer\n9.Exit"))
        print("*"*150)
        match n:
            case 0:
                self.account_details()
            case 1:
                self.check_bal()
            case 2:
                self.deposit()
            case 3:
                self.withdraw()
            case 4:
                self.mini_statement()
            case 5:
                self.cust_update()
            case 6:
                self.pin_change()
            case 7:
                print("Today Rate of Interest",self.roi)
            case 8:
                self.transfer()
            case _:
                return
        return cls.home(self)
                
obj=Bank("venky",23,'venky@gmail.com',7465784367,"hyderabad",980860790546,'PANC2345O9','15-07-2001','male',1234)  
obj1=Bank("venkat",25,'venkat@gmail.com',7465784368,"dilshuknagar",980860790546,'PANC234510','15-07-2002','male',9876) 
# print(Bank.no_cust)
# print (obj.__dict__) 
# print (obj1.__dict__)
# print(Bank.cust_details) 
# Bank.check_bal(obj)
Bank.concat_cust_trans(obj,101)
# Bank.mini_statement(obj1)
# Bank.check_bal(obj)

# def main(cls):
#     acc_no=int(input("Enter the Account_no:"))
#     pin=int(input("Enter the Pin_no:"))
#     if acc_no in cls.cust_details and cls.cust_details[acc_no].pin == pin:
#         self = cls.cust_details[acc_no]
#         cls.home(self)
#     else:
#         print("Invalid  account no or pin")
# main(Bank)

# %%
import datetime
class Bank:
    bann_name="CANARABANK"
    branch="hyd"
    branch_code=1600
    ifsc="CNRB001600"
    roi=7
    no_cust=0
    cust_details={}
    cust_transactions={}
    def __init__(self,name,age,email,phone,address,adhaar,pancard,dob,gender,pin,bal=0):
        self.name=name
        self.age=age
        self.email=email
        self.phone=phone
        self.address=address
        self.adhaar=adhaar
        self.pancard=pancard
        self.dob=dob
        self.gender=gender
        self.pin=pin
        self.bal=bal
        self.no_cust_inc()
        self.account_no=100+self.no_cust
        self.concat_cust_details(self.account_no,self)

    @classmethod
    def no_cust_inc(cls):
        cls.no_cust+=1

    @classmethod
    def concat_cust_details(cls,acc_no,obj):
        cls.cust_details[acc_no]=obj

    @classmethod
    def change_ROI(cls):
        cls.roi=int(input("enter the RoI"))
        print("Roi is changed")
obj1=Bank("venky",23,'venky@gmail.com',7465784367,"hyderabad",980860790546,'PANC2345O9','15-07-2001','male',1234)
print(obj1.__dict__)
Bank.concat_cust_details(obj1)
# Out:
# {'name': 'venky', 'age': 23, 'email': 'venky@gmail.com', 'phone': 7465784367, 'address': 'hyderabad', 'adhaar': 980860790546, 'pancard': 'PANC2345O9', 'dob': '15-07-2001', 'gender': 'male', 'pin': 1234, 'bal': 0, 'account_no': 101}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\venka\Documents\GitHub\basic-python1\python-Qspy\oops\class\venky\class.ipynb Cell 12 line 4
#      <a href='vscode-notebook-cell:/c%3A/Users/venka/Documents/GitHub/basic-python1/python-Qspy/oops/class/venky/class.ipynb#X14sZmlsZQ%3D%3D?line=38'>39</a> obj1=Bank("venky",23,'venky@gmail.com',7465784367,"hyderabad",980860790546,'PANC2345O9','15-07-2001','male',1234)
#      <a href='vscode-notebook-cell:/c%3A/Users/venka/Documents/GitHub/basic-python1/python-Qspy/oops/class/venky/class.ipynb#X14sZmlsZQ%3D%3D?line=39'>40</a> print(obj1.__dict__)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/venka/Documents/GitHub/basic-python1/python-Qspy/oops/class/venky/class.ipynb#X14sZmlsZQ%3D%3D?line=40'>41</a> Bank.concat_cust_details(obj1)
#
# TypeError: Bank.concat_cust_details() missing 1 required positional argument: 'obj'
