# %%
class shopping_app:
    a_name="Shopping App"
    reg_no="1274652"
    address="dilshuknagar"
    phone=897627816
    cart={}
    def __init__(self):
        self.products={"cap":200,
    "casual shoes":1000,
    "flip flops":500,
    "jocket":1500,
    "sandals":800,
    "shirt":650,"shorts":300,
    "sneakers":700,"sweatshirts":750,
    "trackpants":500,
    "tshirts":300,"wallets":300,"laptop":65000,"head set":3000,
    "mobile":10000,"smart watch":1750,
    "trimmer":1500,
    "mixer":3000,"fridge":13000,"smart tv":16500,"tab":8000,
    "mouse":700,"monitor":7750,
    "key board":500,"television":23500,"fridge":13000,"kettle":1000,"induction stove":3000,
    "cooker":1500,"washing machine":20000,
    "geyser":2700, "stand fan":1500,
    "dry iron":1200,"ac":30000,"inverter":20000
    }
    def fashion(self):
        print('Fashion     '," "*10,'Price')
        print("-"*30)
        print("caps        "," "*10,350)
        print("casual shoes"," "*10,1000)
        print("flip flops  "," "*10,500)
        print("jocket      "," "*10,1500)
        print("sandals     "," "*10,800)
        print("shirt       "," "*10,650)
        print("shorts      "," "*10,300)
        print("sneakers    "," "*10,700)
        print("sweatshirts "," "*10,750)
        print("trackpants  "," "*10,400)
        print("wallets     "," "*10,300)
    def electronics(self):
        print('Electronics       '," "*10,'Price')
        print("-"*37)
        print("laptop       "," "*10,65000)
        print("head set     "," "*10,3000)
        print("mobile       "," "*10,10000)
        print("smart watch  "," "*10,1750)
        print("trimmer      "," "*10,1500)
        print("mixer        "," "*10,3000)
        print("fridge       "," "*10,13000)
        print("smart tv     "," "*10,16500)
        print("tab          "," "*10,8000)
        print("key board    "," "*10,500)
    def appliances(self):
        print('Appliances       '," "*10,'Price')
        print("-"*30)
        print("television       "," "*10,23500)
        print("kettle           "," "*10,1000)
        print("induction stove  "," "*10,3000)
        print("cooker           "," "*10,1500)
        print("washing machine  "," "*10,20000)
        print("geyser           "," "*10,2700)
        print("stand fan        "," "*10,2200)
        print("dry iron         "," "*10,1200)
        print("fridge           "," "*10,12000)
        print("ac               "," "*10,30000)
        print("inverter         "," "*10,20000)
    def display(self):
        res=0
        ord={}
        ord1={}
        while True:
            try:
                opt=int(input("choose the option\n1.choose products:\n2.cart\n3.confirm\n4.bill\n5.exit:"))
            except ValueError:
                print("plz provide numbers only")
            except:
                print("enter valid inputs only")
            if opt==1:
                try:
                    n=input("enter the item you want:")
                except UnboundLocalError:
                    print("plz enter valid data")
                if n in self.products:
                    res+=self.products[n]
                    ord1.update({n:self.products[n]})
                    if n in ord:
                        ord[n]+=1
                    else:
                        ord[n]=1
                else:
                    print("item not present")
            elif opt==2:
                print("the selected items are")
                print("-"*30)
                for it,pri in ord1.items():
                    print(f'{it} {pri}')
            elif opt==3:
                print()
                print("the quantity of the items:")
                print("-"*30)
                for item,quan in ord.items():
                    print(f'{item} X {quan} = {self.products[item]*quan}')
            elif opt==4:
                print()
                print("the total bill of the items are:",res)
            elif opt==5:
                break

# %%
class payment:
    def __init__(self,upi,pin):
        self.upi=upi
        self.pin=pin
        self.c_pin=9876
        self.c_upi='7386624002@paytm'
    def valid(self):
        if self.c_pin==self.pin and self.c_upi==self.upi:
            print("payment successful")
            print("your order is placed")
        else:
            print("wrong upi or pin")

# %%
class Shopping:
    def __init__(self,un,pw):
        self.username="venky"
        self.pas=1234
        self.un=un
        self.pw=pw
    def Validation(self):
        if self.un==self.username and self.pw==self.pas:
            print("you are a valid user")
            obj=shopping_app()
            while True:
                try:
                    option=int(input("enter choice\n1.fashion\n2.electronics\n3.appliances\n4.display\n5.payment\n6.exit"))
                except ValueError:
                    print("please provide numbers only")
                except:
                    print("enter valid inputs")
                print("*"*50)
                if option==1:
                    obj.fashion()
                elif option==2:
                    obj.electronics()
                elif option==3:
                    obj.appliances()
                elif option==4:
                    obj.display()
                elif option==5:
                    upi=input("enter upi:")
                    pin=int(input("enter pin:"))
                    obj1=payment(upi,pin)
                    obj1.valid()
                elif option==6:
                    print("----thanks for visiting my Shopping Application-----")
                    break
                else:
                    print("invalid option...plz choose valid option")
        else:
            print("you are not valid user")
try:
    un=input("enter username:")
    pw=int(input("enter pin:"))
except ValueError:
    print("enter valid input")
obj=Shopping(un,pw)
obj.Validation()
# Out:
# you are a valid user
# **************************************************
# Fashion                 Price
# ------------------------------
# caps                    350
# casual shoes            1000
# flip flops              500
# jocket                  1500
# sandals                 800
# shirt                   650
# shorts                  300
# sneakers                700
# sweatshirts             750
# trackpants              400
# wallets                 300
# **************************************************
# Electronics                   Price
# -------------------------------------
# laptop                   65000
# head set                 3000
# mobile                   10000
# smart watch              1750
# trimmer                  1500
# mixer                    3000
# fridge                   13000
# smart tv                 16500
# tab                      8000
# key board                500
# **************************************************
# ...

# %%
print('Appliances     '," "*10,'Price')
print("-"*30)
print("television        "," "*10,23500)
print("kettle"," "*10,1000)
print("induction stove  "," "*10,3000)
print("cooker      "," "*10,1500)
print("washing machine     "," "*10,20000)
print("geyser       "," "*10,2700)
print("stand fan      "," "*10,2200)
print("dry iron   "," "*10,1200)
print("fridge "," "*10,12000)
print("ac  "," "*10,30000)
print("inverter     "," "*10,20000)
# Out:
# Fashion                 Price
# ------------------------------
# caps                    350
# casual shoes            100
# flip flops              130
# jocket                  150
# sandals                 200
# shirt                   200
# shorts                  200
# sneakers                200
# sweatshirts             200
# trackpants              200
# wallets                 200

# %%
# print("Non-Veg Starter"," "*10,'Price')
print("-"*37)
print("laptop       "," "*10,200)
print("head set     "," "*10,250)
print("mobile       "," "*10,250)
print("smart watch  "," "*10,350)
print("trimmer      "," "*10,330)
print("mixer        "," "*10,380)
print("fridge       "," "*10,350)
print("smart tv     "," "*10,250)
print("tab          "," "*10,280)
print("key board    "," "*10,280)
# Out:
# -------------------------------------
# laptop                   200
# head set                 250
# mobile                   250
# smart watch              350
# trimmer                  330
# mixer                    380
# fridge                   350
# smart tv                 250
# tab                      280
# key board                280

# %%
fp=open('items.txt','w')
fp.write('shirt-500')
fp.write('\ntrouser-700')
l=['\nshort-400','\njeans-700','\ntshirt-300','\nshoes-800','\nsandles-600']
fp.writelines(l)
fp.close()

# %%
with open('items.txt') as fp:
    l=list(fp)
    d={}
    for i in l:
        d[i.split('-')[0]]=i.split('-')[1]
    print(d)
# Out:
# {'shirt': '500\n', 'trouser': '700\n', 'short': '400\n', 'jeans': '700\n', 'tshirt': '300\n', 'shoes': '800\n', 'sandles': '600'}

# %%
W='brain'
N=3
str='Python is a programming brain language \n The Human Brain is eighty percent Water \n Kamala scores high in science \n Curious brain learns fast \n Lion is a Land animal'
n=0
for i in str.split('\n'):
    n=n+1
    for j in i.split(' '):
        if W==j:
            print(n)
            break
# Out:
# 1
# 4

# %%
W='brain'
N=3
str1='Python is a programming language \n The Human Brain is eighty percent Water \n Kamala scores high in science \n Curious brain learns fast \n Lion is a Land animal'
def fun(W,N,str1,n=0):
    for i in str1.split('\n'):
        n=n+1
        for j in i.split(' '):
            if W==j:
                print(n)
                return
fun(W,N,str1)
# Out:
# 4

# %%
with open('employee.csv','r') as fp:
    data=fp.readlines()
    n=(input('enter name:'))
    ord={}
    for i in data:
        res=i.split(',')
        for k in res:
            # print('hi',k)
            if k==n:
                # print('hi')
                # print('age:',res[2],'phno:',res[3],'sal:',res[4])
                ord.update({n:res[4]})
                # if n in ord:
                #     ord[n]+=1
                # else:
                #     ord[n]=1
    print(ord)
# Out:
# {'venkatesh': '35000'}
